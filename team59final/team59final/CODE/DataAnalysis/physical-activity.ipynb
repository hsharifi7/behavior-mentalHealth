# %%
# %matplotlib inline

import matplotlib.pyplot as plt

import pandas as pd
import sqlite3

import numpy as np

# %%
statesDF = pd.read_csv('states.csv') 
statesDF.head()
# Out:
#    FIPS        Name
# 0     1     Alabama
# 1     2      Alaska
# 2     4     Arizona
# 3     5    Arkansas
# 4     6  California

# %%
conn = sqlite3.connect("brfss.sqlite")

# %%
query = "select `x.state` as state , count(*) as have_mentalhealth from BRFSS_2017 \
where MENTHLTH is not null and MENTHLTH not in (88, 77, 99) \
group by `x.state`;"

df = pd.read_sql_query(query, conn)
temp = pd.concat([statesDF, df], axis=1, sort=False).drop(['state'], axis=1)

resutlsDF = temp

query = "select `x.state` as state , count(*) as have_no_mentalhealth from BRFSS_2017 \
where MENTHLTH = 88   \
group by `x.state`;"

df = pd.read_sql_query(query, conn)
temp = pd.concat([resutlsDF, df], axis=1, sort=False).drop(['state'], axis=1)

resutlsDF = temp

query = "select `x.state` as state , count(*) as no_workout from BRFSS_2017 \
where `EXERANY2`= 2 \
group by `x.state`;"

df = pd.read_sql_query(query, conn)
temp = pd.concat([resutlsDF, df], axis=1, sort=False).drop(['state'], axis=1)

resutlsDF = temp

query = "select `x.state` as state , count(*) as workout from BRFSS_2017 \
where `EXERANY2` = 1  \
group by `x.state`;"

df = pd.read_sql_query(query, conn)
temp = pd.concat([resutlsDF, df], axis=1, sort=False).drop(['state'], axis=1)



#df.head()
#temp.head()
brfssDF2017 = temp
brfssDF2017.head()
# Out:
#    FIPS        Name  have_mentalhealth  have_no_mentalhealth  no_workout  \
# 0     1     Alabama               2260                  4311        2187
# 1     2      Alaska                987                  2129         696
# 2     4     Arizona               4755                 10514        3498
# 3     5    Arkansas               1604                  3631        1769
# 4     6  California               3268                  5999        1567
#
#    workout
# 0     4043
# 1     2300
# 2    10546
# 3     3110
# 4     6659

# %%
query = "select `x.state` as state , count(*) as have_mentalhealth from BRFSS_2016 \
where MENTHLTH is not null and MENTHLTH not in (88, 77, 99) \
group by `x.state`;"

df = pd.read_sql_query(query, conn)
temp = pd.concat([statesDF, df], axis=1, sort=False).drop(['state'], axis=1)

resutlsDF = temp

query = "select `x.state` as state , count(*) as have_no_mentalhealth from BRFSS_2016 \
where MENTHLTH = 88   \
group by `x.state`;"

df = pd.read_sql_query(query, conn)
temp = pd.concat([resutlsDF, df], axis=1, sort=False).drop(['state'], axis=1)

resutlsDF = temp

query = "select `x.state` as state , count(*) as no_workout from BRFSS_2016 \
where `EXERANY2`= 2 \
group by `x.state`;"

df = pd.read_sql_query(query, conn)
temp = pd.concat([resutlsDF, df], axis=1, sort=False).drop(['state'], axis=1)

resutlsDF = temp

query = "select `x.state` as state , count(*) as workout from BRFSS_2016 \
where `EXERANY2` = 1  \
group by `x.state`;"

df = pd.read_sql_query(query, conn)
temp = pd.concat([resutlsDF, df], axis=1, sort=False).drop(['state'], axis=1)




#df.head()
#temp.head()
brfssDF2016 = temp
brfssDF2016.head()
# Out:
#    FIPS        Name  have_mentalhealth  have_no_mentalhealth  no_workout  \
# 0   1.0     Alabama               2452                  4415        2178
# 1   2.0      Alaska                949                  1893         593
# 2   4.0     Arizona               3158                  7643        2809
# 3   5.0    Arkansas               1600                  3596        1893
# 4   6.0  California               3951                  7355        2231
#
#    workout
# 0     4835
# 1     2317
# 2     8112
# 3     3392
# 4     9155

# %%
query = "select `x.state` as state , count(*) as have_mentalhealth from BRFSS_2015 \
where MENTHLTH is not null and MENTHLTH not in (88, 77, 99) \
group by `x.state`;"

df = pd.read_sql_query(query, conn)
temp = pd.concat([statesDF, df], axis=1, sort=False).drop(['state'], axis=1)

resutlsDF = temp

query = "select `x.state` as state , count(*) as have_no_mentalhealth from BRFSS_2015 \
where MENTHLTH = 88   \
group by `x.state`;"

df = pd.read_sql_query(query, conn)
temp = pd.concat([resutlsDF, df], axis=1, sort=False).drop(['state'], axis=1)

resutlsDF = temp

query = "select `x.state` as state , count(*) as no_workout from BRFSS_2015 \
where `EXERANY2`= 2 \
group by `x.state`;"

df = pd.read_sql_query(query, conn)
temp = pd.concat([resutlsDF, df], axis=1, sort=False).drop(['state'], axis=1)

resutlsDF = temp

query = "select `x.state` as state , count(*) as workout from BRFSS_2015 \
where `EXERANY2` = 1  \
group by `x.state`;"

df = pd.read_sql_query(query, conn)
temp = pd.concat([resutlsDF, df], axis=1, sort=False).drop(['state'], axis=1)


#df.head()
#temp.head()
brfssDF2015 = temp
brfssDF2015.head()
# Out:
#    FIPS        Name  have_mentalhealth  have_no_mentalhealth  no_workout  \
# 0     1     Alabama               2579                  5206        2418
# 1     2      Alaska               1196                  2372         772
# 2     4     Arizona               2366                  5425        1727
# 3     5    Arkansas               1545                  3574        1769
# 4     6  California               4477                  8022        2111
#
#    workout
# 0     4851
# 1     2648
# 2     5439
# 3     2958
# 4     8793

# %%
query = "select `x.state` as state , count(*) as have_mentalhealth from BRFSS_2014 \
where MENTHLTH is not null and MENTHLTH not in (88, 77, 99) \
group by `x.state`;"

df = pd.read_sql_query(query, conn)
temp = pd.concat([statesDF, df], axis=1, sort=False).drop(['state'], axis=1)

resutlsDF = temp

query = "select `x.state` as state , count(*) as have_no_mentalhealth from BRFSS_2014 \
where MENTHLTH = 88   \
group by `x.state`;"

df = pd.read_sql_query(query, conn)
temp = pd.concat([resutlsDF, df], axis=1, sort=False).drop(['state'], axis=1)

resutlsDF = temp

query = "select `x.state` as state , count(*) as no_workout from BRFSS_2014 \
where `EXERANY2`= 2 \
group by `x.state`;"

df = pd.read_sql_query(query, conn)
temp = pd.concat([resutlsDF, df], axis=1, sort=False).drop(['state'], axis=1)

resutlsDF = temp

query = "select `x.state` as state , count(*) as workout from BRFSS_2014 \
where `EXERANY2` = 1  \
group by `x.state`;"

df = pd.read_sql_query(query, conn)
temp = pd.concat([resutlsDF, df], axis=1, sort=False).drop(['state'], axis=1)


#df.head()
#temp.head()
brfssDF2014 = temp
brfssDF2014.head()
# Out:
#    FIPS        Name  have_mentalhealth  have_no_mentalhealth  no_workout  \
# 0     1     Alabama               2906                  5568        2583
# 1     2      Alaska               1358                  2933         815
# 2     4     Arizona               4180                 10453        3345
# 3     5    Arkansas               1559                  3566        1832
# 4     6  California               2987                  5771        1637
#
#    workout
# 0     6056
# 1     3563
# 2    11484
# 3     3418
# 4     6185

# %%
query = "select `x.state` as state , count(*) as have_mentalhealth from BRFSS_2013 \
where MENTHLTH is not null and MENTHLTH not in (88, 77, 99) \
group by `x.state`;"

df = pd.read_sql_query(query, conn)
temp = pd.concat([statesDF, df], axis=1, sort=False).drop(['state'], axis=1)

resutlsDF = temp

query = "select `x.state` as state , count(*) as have_no_mentalhealth from BRFSS_2013 \
where MENTHLTH = 88   \
group by `x.state`;"

df = pd.read_sql_query(query, conn)
temp = pd.concat([resutlsDF, df], axis=1, sort=False).drop(['state'], axis=1)

resutlsDF = temp

query = "select `x.state` as state , count(*) as no_workout from BRFSS_2013 \
where `EXERANY2`= 2 \
group by `x.state`;"

df = pd.read_sql_query(query, conn)
temp = pd.concat([resutlsDF, df], axis=1, sort=False).drop(['state'], axis=1)

resutlsDF = temp

query = "select `x.state` as state , count(*) as workout from BRFSS_2013 \
where `EXERANY2` = 1  \
group by `x.state`;"

df = pd.read_sql_query(query, conn)
temp = pd.concat([resutlsDF, df], axis=1, sort=False).drop(['state'], axis=1)



#df.head()
#temp.head()
brfssDF2013 = temp
brfssDF2013.head()
# Out:
#    FIPS        Name  have_mentalhealth  have_no_mentalhealth  no_workout  \
# 0     1     Alabama               2131                  4203        2077
# 1     2      Alaska               1426                  3079         981
# 2     4     Arizona               1314                  2866        1048
# 3     5    Arkansas               1616                  3523        1777
# 4     6  California               4090                  7320        2099
#
#    workout
# 0     4087
# 1     3294
# 2     2862
# 3     3094
# 4     8091

# %%
query = "select `x.state` as state , count(*) as have_mentalhealth from BRFSS_2012 \
where MENTHLTH is not null and MENTHLTH not in (88, 77, 99) \
group by `x.state`;"

df = pd.read_sql_query(query, conn)
temp = pd.concat([statesDF, df], axis=1, sort=False).drop(['state'], axis=1)

resutlsDF = temp

query = "select `x.state` as state , count(*) as have_no_mentalhealth from BRFSS_2012 \
where MENTHLTH = 88   \
group by `x.state`;"

df = pd.read_sql_query(query, conn)
temp = pd.concat([resutlsDF, df], axis=1, sort=False).drop(['state'], axis=1)

resutlsDF = temp

query = "select `x.state` as state , count(*) as no_workout from BRFSS_2012 \
where `EXERANY2`= 2 \
group by `x.state`;"

df = pd.read_sql_query(query, conn)
temp = pd.concat([resutlsDF, df], axis=1, sort=False).drop(['state'], axis=1)

resutlsDF = temp

query = "select `x.state` as state , count(*) as workout from BRFSS_2012 \
where `EXERANY2` = 1  \
group by `x.state`;"

df = pd.read_sql_query(query, conn)
temp = pd.concat([resutlsDF, df], axis=1, sort=False).drop(['state'], axis=1)


#df.head()
#temp.head()
brfssDF2012 = temp
brfssDF2012.head()
# Out:
#    FIPS        Name  have_mentalhealth  have_no_mentalhealth  no_workout  \
# 0     1     Alabama               3217                  5606        2699
# 1     2      Alaska               1250                  3005         871
# 2     4     Arizona               2281                  4907        1738
# 3     5    Arkansas               1755                  3305        1750
# 4     6  California               5223                  9272        2643
#
#    workout
# 0     6315
# 1     3465
# 2     5547
# 3     3424
# 4    11028

# %%
query = "select `x.state` as state , count(*) as have_mentalhealth from BRFSS_2011 \
where MENTHLTH is not null and MENTHLTH not in (88, 77, 99) \
group by `x.state`;"

df = pd.read_sql_query(query, conn)
temp = pd.concat([statesDF, df], axis=1, sort=False).drop(['state'], axis=1)

resutlsDF = temp

query = "select `x.state` as state , count(*) as have_no_mentalhealth from BRFSS_2011 \
where MENTHLTH = 88   \
group by `x.state`;"

df = pd.read_sql_query(query, conn)
temp = pd.concat([resutlsDF, df], axis=1, sort=False).drop(['state'], axis=1)

resutlsDF = temp

query = "select `x.state` as state , count(*) as no_workout from BRFSS_2011 \
where `EXERANY2`= 2 \
group by `x.state`;"

df = pd.read_sql_query(query, conn)
temp = pd.concat([resutlsDF, df], axis=1, sort=False).drop(['state'], axis=1)

resutlsDF = temp

query = "select `x.state` as state , count(*) as workout from BRFSS_2011 \
where `EXERANY2` = 1  \
group by `x.state`;"

df = pd.read_sql_query(query, conn)
temp = pd.concat([resutlsDF, df], axis=1, sort=False).drop(['state'], axis=1)



#df.head()
#temp.head()
brfssDF2011 = temp
brfssDF2011.head()
# Out:
#    FIPS        Name  have_mentalhealth  have_no_mentalhealth  no_workout  \
# 0     1     Alabama               2592                  4967        2614
# 1     2      Alaska               1079                  2343         776
# 2     4     Arizona               2106                  4305        1541
# 3     5    Arkansas               1526                  3091        1557
# 4     6  California               6449                 11453        3195
#
#    workout
# 0     4856
# 1     2573
# 2     4656
# 3     2892
# 4    13732

# %%
query = "select `x.state` as state , count(*) as have_mentalhealth from BRFSS_2010 \
where MENTHLTH is not null and MENTHLTH not in (88, 77, 99) \
group by `x.state`;"

df = pd.read_sql_query(query, conn)
temp = pd.concat([statesDF, df], axis=1, sort=False).drop(['state'], axis=1)

resutlsDF = temp

query = "select `x.state` as state , count(*) as have_no_mentalhealth from BRFSS_2010 \
where MENTHLTH = 88   \
group by `x.state`;"

df = pd.read_sql_query(query, conn)
temp = pd.concat([resutlsDF, df], axis=1, sort=False).drop(['state'], axis=1)

resutlsDF = temp

query = "select `x.state` as state , count(*) as no_workout from BRFSS_2010 \
where `EXERANY2`= 2 \
group by `x.state`;"

df = pd.read_sql_query(query, conn)
temp = pd.concat([resutlsDF, df], axis=1, sort=False).drop(['state'], axis=1)

resutlsDF = temp

query = "select `x.state` as state , count(*) as workout from BRFSS_2010 \
where `EXERANY2` = 1  \
group by `x.state`;"

df = pd.read_sql_query(query, conn)
temp = pd.concat([resutlsDF, df], axis=1, sort=False).drop(['state'], axis=1)


#df.head()
#temp.head()
brfssDF2010 = temp
brfssDF2010.head()
# Out:
#    FIPS        Name  have_mentalhealth  have_no_mentalhealth  no_workout  \
# 0   1.0     Alabama               2385                  5102        2650
# 1   2.0      Alaska                603                  1287         482
# 2   4.0     Arizona               1805                  3884        1496
# 3   5.0    Arkansas               1219                  2701        1366
# 4   6.0  California               6333                 11327        3718
#
#    workout
# 0     5005
# 1     1473
# 2     4251
# 3     2649
# 4    14057

# %%
query = "select `x.state` as state , count(*) as have_mentalhealth from BRFSS_2009 \
where MENTHLTH is not null and MENTHLTH not in (88, 77, 99) \
group by `x.state`;"

df = pd.read_sql_query(query, conn)
temp = pd.concat([statesDF, df], axis=1, sort=False).drop(['state'], axis=1)

resutlsDF = temp

query = "select `x.state` as state , count(*) as have_no_mentalhealth from BRFSS_2009 \
where MENTHLTH = 88   \
group by `x.state`;"

df = pd.read_sql_query(query, conn)
temp = pd.concat([resutlsDF, df], axis=1, sort=False).drop(['state'], axis=1)

resutlsDF = temp

query = "select `x.state` as state , count(*) as no_workout from BRFSS_2009 \
where `EXERANY2`= 2 \
group by `x.state`;"

df = pd.read_sql_query(query, conn)
temp = pd.concat([resutlsDF, df], axis=1, sort=False).drop(['state'], axis=1)

resutlsDF = temp

query = "select `x.state` as state , count(*) as workout from BRFSS_2009 \
where `EXERANY2` = 1  \
group by `x.state`;"

df = pd.read_sql_query(query, conn)
temp = pd.concat([resutlsDF, df], axis=1, sort=False).drop(['state'], axis=1)


#df.head()
#temp.head()
brfssDF2009 = temp
brfssDF2009.head()
# Out:
#    FIPS        Name  have_mentalhealth  have_no_mentalhealth  no_workout  \
# 0   1.0     Alabama               2153                  4463        2391
# 1   2.0      Alaska                738                  1625         568
# 2   4.0     Arizona               1736                  3667        1375
# 3   5.0    Arkansas               1207                  2697        1397
# 4   6.0  California               6092                 11224        3767
#
#    workout
# 0     4391
# 1     1854
# 2     4094
# 3     2604
# 4    13621

# %%
query = "select `x.state` as state , count(*) as have_mentalhealth from BRFSS_2008 \
where MENTHLTH is not null and MENTHLTH not in (88, 77, 99) \
group by `x.state`;"

df = pd.read_sql_query(query, conn)
temp = pd.concat([statesDF, df], axis=1, sort=False).drop(['state'], axis=1)

resutlsDF = temp

query = "select `x.state` as state , count(*) as have_no_mentalhealth from BRFSS_2008 \
where MENTHLTH = 88   \
group by `x.state`;"

df = pd.read_sql_query(query, conn)
temp = pd.concat([resutlsDF, df], axis=1, sort=False).drop(['state'], axis=1)

resutlsDF = temp

query = "select `x.state` as state , count(*) as no_workout from BRFSS_2008 \
where `EXERANY2`= 2 \
group by `x.state`;"

df = pd.read_sql_query(query, conn)
temp = pd.concat([resutlsDF, df], axis=1, sort=False).drop(['state'], axis=1)

resutlsDF = temp

query = "select `x.state` as state , count(*) as workout from BRFSS_2008 \
where `EXERANY2` = 1  \
group by `x.state`;"

df = pd.read_sql_query(query, conn)
temp = pd.concat([resutlsDF, df], axis=1, sort=False).drop(['state'], axis=1)


#df.head()
#temp.head()
brfssDF2008 = temp
brfssDF2008.head()
# Out:
#    FIPS        Name  have_mentalhealth  have_no_mentalhealth  no_workout  \
# 0   1.0     Alabama               2217                  4117        2181
# 1   2.0      Alaska                830                  1736         679
# 2   4.0     Arizona               1871                  4204        1718
# 3   5.0    Arkansas               1680                  3892        1925
# 4   6.0  California               4163                  7332        2645
#
#    workout
# 0     4300
# 1     1969
# 2     4438
# 3     3761
# 4     8951

# %%
query = "select `x.state` as state , count(*) as have_mentalhealth from BRFSS_2007 \
where MENTHLTH is not null and MENTHLTH not in (88, 77, 99) \
group by `x.state`;"

df = pd.read_sql_query(query, conn)
temp = pd.concat([statesDF, df], axis=1, sort=False).drop(['state'], axis=1)

resutlsDF = temp

query = "select `x.state` as state , count(*) as have_no_mentalhealth from BRFSS_2007 \
where MENTHLTH = 88   \
group by `x.state`;"

df = pd.read_sql_query(query, conn)
temp = pd.concat([resutlsDF, df], axis=1, sort=False).drop(['state'], axis=1)

resutlsDF = temp

query = "select `x.state` as state , count(*) as no_workout from BRFSS_2007 \
where `EXERANY2`= 2 \
group by `x.state`;"

df = pd.read_sql_query(query, conn)
temp = pd.concat([resutlsDF, df], axis=1, sort=False).drop(['state'], axis=1)

resutlsDF = temp

query = "select `x.state` as state , count(*) as workout from BRFSS_2007 \
where `EXERANY2` = 1  \
group by `x.state`;"

df = pd.read_sql_query(query, conn)
temp = pd.concat([resutlsDF, df], axis=1, sort=False).drop(['state'], axis=1)


#df.head()
#temp.head()
brfssDF2007 = temp
brfssDF2007.head()
# Out:
#    FIPS        Name  have_mentalhealth  have_no_mentalhealth  no_workout  \
# 0   1.0     Alabama               2342                  4721        2465
# 1   2.0      Alaska                821                  1629         562
# 2   4.0     Arizona               1522                  3135        1226
# 3   5.0    Arkansas               1780                  3808        1808
# 4   6.0  California               2065                  3599        1240
#
#    workout
# 0     4781
# 1     1983
# 2     3501
# 3     3916
# 4     4450

# %%
brfssDF2017['year']=2017
brfssDF2016['year']=2016
brfssDF2015['year']=2015
brfssDF2014['year']=2014
brfssDF2013['year']=2013
brfssDF2012['year']=2012
brfssDF2011['year']=2011
brfssDF2010['year']=2010
brfssDF2009['year']=2009
brfssDF2008['year']=2008
brfssDF2007['year']=2007

# %%
brfssDF = pd.concat([brfssDF2017, brfssDF2016, brfssDF2015, brfssDF2014, brfssDF2013, brfssDF2012, 
                     brfssDF2011, brfssDF2010, brfssDF2009, brfssDF2008, brfssDF2007])
brfssDF = brfssDF.dropna() 
brfssDF = brfssDF.reset_index()
brfssDF['FIPS'] = brfssDF['FIPS'].astype(int) 
brfssDF
# Out:
#      index  FIPS                  Name  have_mentalhealth  \
# 0        0     1               Alabama               2260
# 1        1     2                Alaska                987
# 2        2     4               Arizona               4755
# 3        3     5              Arkansas               1604
# 4        4     6            California               3268
# 5        5     8              Colorado               3373
# 6        6     9           Connecticut               3146
# 7        7    10              Delaware               1216
# 8        8    11  District of Columbia               1258
# 9        9    12               Florida               6684
# 10      10    13               Georgia               1753
# 11      11    15                Hawaii               2396
# 12      12    16                 Idaho               1634
# 13      13    17              Illinois               1946
# 14      14    18               Indiana               4716
# 15      15    19                  Iowa               2267
# 16      16    20                Kansas               6494
# 17      17    21              Kentucky               2987
# 18      18    22             Louisiana               1743
# 19      19    23                 Maine               3304
# 20      20    24              Maryland               4055
# 21      21    25         Massachusetts               2394
# 22      22    26              Michigan               3874
# 23      23    27             Minnesota               4988
# 24      24    28           Mississippi               1660
# 25      25    29              Missouri               2331
# 26      26    30               Montana               1708
# 27      27    31              Nebraska               4399
# 28      28    32                Nevada               1211
# 29      29    33         New Hampshire               1750
# ..     ...   ...                   ...                ...
# 553     23    27             Minnesota               1345
# 554     24    28           Mississippi               2447
# 555     25    29              Missouri               1750
# 556     26    30               Montana               1919
# 557     27    31              Nebraska               2856
# 558     28    32                Nevada               1533
# 559     29    33         New Hampshire               1940
mentalhealth']/(temp['have_mentalhealth']+temp['have_no_mentalhealth'])

temp['p_workout'] = temp['workout']/(temp['workout']+temp['no_workout'])
temp['p_no_workout'] =  temp['no_workout']/(temp['workout']+temp['no_workout'])


temp.to_csv("pdata_quang.csv", index=False)

# %%
grouped = brfssDF.groupby(['year'])['have_mentalhealth', 'have_no_mentalhealth', 'no_workout', 'workout'].apply(lambda x: x.astype(int).sum())
grouped.reset_index()
# Out:
#     year  have_mentalhealth  have_no_mentalhealth  no_workout  workout
# 0   2007             131115                290027      112510   315387
# 1   2008             127333                278337      114049   297478
# 2   2009             130123                293181      117858   311690
# 3   2010             137003                303623      122944   325677
# 4   2011             156389                340313      130303   353170
# 5   2012             148526                319143      118540   355588
# 6   2013             148648                334490      125314   332429
# 7   2014             137571                319131      112926   350011
# 8   2015             132972                301076      107444   296020
# 9   2016             148541                328600      123552   360692
# 10  2017             142679                300134      114783   301030

# %%
grouped['p_have_mentalhealth'] = grouped['have_mentalhealth']/(grouped['have_mentalhealth']+grouped['have_no_mentalhealth'])
grouped['p_have_no_mentalhealth'] =  grouped['have_no_mentalhealth']/(grouped['have_mentalhealth']+grouped['have_no_mentalhealth'])


grouped['p_workout'] = grouped['workout']/(grouped['workout']+grouped['no_workout'])
grouped['p_no_workout'] =  grouped['no_workout']/(grouped['workout']+grouped['no_workout'])

grouped = grouped.drop(grouped.columns[[0,1,2,3]], axis=1).reset_index()
grouped
# Out:
#     year  p_have_mentalhealth  p_have_no_mentalhealth  p_workout  p_no_workout
# 0   2007             0.311332                0.688668   0.737063      0.262937
# 1   2008             0.313883                0.686117   0.722864      0.277136
# 2   2009             0.307398                0.692602   0.725623      0.274377
# 3   2010             0.310928                0.689072   0.725951      0.274049
# 4   2011             0.314855                0.685145   0.730485      0.269515
# 5   2012             0.317588                0.682412   0.749983      0.250017
# 6   2013             0.307672                0.692328   0.726235      0.273765
# 7   2014             0.301227                0.698773   0.756066      0.243934
# 8   2015             0.306353                0.693647   0.733696      0.266304
# 9   2016             0.311315                0.688685   0.744856      0.255144
# 10  2017             0.322211                0.677789   0.723955      0.276045

# %%
#dropping those years that we don't have data for

grouped.loc[grouped['p_no_workout'] == 0.500000, 'p_no_workout'] = float('nan') 
grouped.loc[grouped['p_workout'] == 0.500000, 'p_workout'] = float('nan') 
grouped = grouped.dropna()

grouped
# Out:
#     year  p_have_mentalhealth  p_have_no_mentalhealth  p_workout  p_no_workout
# 0   2007             0.311332                0.688668   0.737063      0.262937
# 1   2008             0.313883                0.686117   0.722864      0.277136
# 2   2009             0.307398                0.692602   0.725623      0.274377
# 3   2010             0.310928                0.689072   0.725951      0.274049
# 4   2011             0.314855                0.685145   0.730485      0.269515
# 5   2012             0.317588                0.682412   0.749983      0.250017
# 6   2013             0.307672                0.692328   0.726235      0.273765
# 7   2014             0.301227                0.698773   0.756066      0.243934
# 8   2015             0.306353                0.693647   0.733696      0.266304
# 9   2016             0.311315                0.688685   0.744856      0.255144
# 10  2017             0.322211                0.677789   0.723955      0.276045

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
ax.plot(grouped['year'],grouped['p_have_mentalhealth'])
start, end = ax.get_xlim()
ax.set_xlim(2006, 2018)

ax.set_ylim(0, 1.4)

ax.plot(grouped['year'],grouped['p_no_workout'])

plt.ylabel('Poportion of survey pupoluation')
plt.xlabel('Survey years')

plt.legend(loc='upper left', labels=['Have mental health', 'Do not workout'])

plt.savefig('Quang.pdf')

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
ax.plot(grouped['year'],grouped['p_have_no_mentalhealth'])
start, end = ax.get_xlim()
ax.set_xlim(2006, 2018)

ax.set_ylim(0, 1.6)

ax.plot(grouped['year'],grouped['p_workout'])

plt.legend(loc='upper left')

plt.show()
